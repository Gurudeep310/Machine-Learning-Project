# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("bpp_training_data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   300000 non-null  int64
#  1   SalePrice                 300000 non-null  int64
#  2   MachineID                 300000 non-null  int64
#  3   ModelID                   300000 non-null  int64
#  4   datasource                300000 non-null  int64
#  5   auctioneerID              300000 non-null  int64
#  6   YearMade                  300000 non-null  int64
#  7   MachineHoursCurrentMeter  300000 non-null  int64
#  8   UsageBand                 300000 non-null  int64
#  9   fiModelDesc               300000 non-null  int64
#  10  fiBaseModel               300000 non-null  int64
#  11  fiSecondaryDesc           300000 non-null  int64
#  12  fiModelSeries             300000 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                              count          mean            std        min  \
# SalesID                   300000.0  1.658908e+06  374118.248946  1139246.0
# SalePrice                 300000.0  3.099134e+04   22836.063512     4750.0
# MachineID                 300000.0  1.186822e+06  390194.137716        0.0
# ModelID                   300000.0  6.314940e+03    5531.594504       43.0
# datasource                300000.0  1.323797e+02       3.604955      121.0
# auctioneerID              300000.0  1.772646e+02     105.040516        2.0
# YearMade                  300000.0  1.905679e+03     279.335539     1000.0
# MachineHoursCurrentMeter  300000.0  1.772646e+02     105.040516        2.0
# UsageBand                 300000.0  1.938333e-01       0.674342        0.0
# fiModelDesc               300000.0  1.660867e+03    1223.306905        1.0
# fiBaseModel               300000.0  5.467053e+02     447.959135        1.0
# ...

# %%
df = df.sample(500)
sns.heatmap(df.corr(), annot=True)

# %%
X = df.drop(['SalesID','SalePrice','MachineID','ModelID','datasource','auctioneerID','UsageBand','fiModelDesc','fiBaseModel','fiSecondaryDesc','fiModelDescriptor','fiProductClassDesc','ProductGroup','ProductGroupDesc','saleDay'],axis = 1)
y = df[['SalePrice']]

# %%
# Split the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-799baa36678b> in <module>()
#       1 # Split the data into train and test
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2417     arrays = indexable(*arrays)
#    2418
# -> 2419     n_samples = _num_samples(arrays[0])
#    2420     n_train, n_test = _validate_shuffle_split(
#    2421         n_samples, test_size, train_size, default_test_size=0.25
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     263             x = np.asarray(x)
#     264         else:
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)

# %%
X_test_scaled = ss.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression().fit(X_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1e2e364b3a14> in <module>()
#       1 from sklearn.linear_model import LinearRegression
#       2
# ----> 3 linear_model = LinearRegression().fit(X_train_scaled,y_train)
#
# NameError: name 'X_train_scaled' is not defined

# %%
linear_model.intercept_
# Out:
# array([32321.16533333])

# %%
linear_model.coef_
# Out:
# array([[  2591.68247744,   -680.93251435,   3529.45429986,
#             94.34313424,    379.53898906,  -6019.40809101,
#           -325.62419065,   2452.63533656,  -1510.20008869,
#          14851.43694888,   -477.73320978,   3872.94438453,
#           -487.84864377,  18328.90818224,  -4728.19688522,
#          -5625.33322848,    287.36316276,  -2792.91932834,
#          17301.00059991, -13155.10402037,  -4422.97239435,
#           -788.80891766,   1908.16295144,   7927.56849081,
#          -1066.99449949,  -1066.99449949,  -1066.99449949,
#          12579.21785473, -10271.08973694,  -3750.41045458,
#          -8261.75406556,  17367.91489599,  -1704.48735115,
#          43153.48035771,   6097.55889371, -32826.18510484,
#          -6556.44560806,  -6556.44560806,   1242.88018977,
#           3089.1851503 ,   -680.93251435]])

# %%
y_pred = linear_model.predict(X_test_scaled)

# %%
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,125)
result["Actual"] = y_test.values

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(result["Actual"],result["Predictions_LR"])
# Out:
# 13111.888991367992

# %%
result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)

# %%
SAE = result["Error_LR"].sum() #Sum of Absolute Errors

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.28889271419618556

# %% [markdown]
# # Schoastic Gradient Desenct Method

# %%
from sklearn.linear_model import SGDRegressor  # Schocastic Gradient Descent Method
sgd = SGDRegressor(max_iter=1000, tol=1e-3)
sgd.fit(X_train_scaled, np.reshape(y_train.values,y_train.shape[0]))
# Out:
# SGDRegressor()

# %%
sgd.coef_
# Out:
# array([ 3539.44876358,   680.94803224,  3821.53541537,   593.5118891 ,
#          105.9025509 , -1500.92759874,  -217.06993993,   -61.75603278,
#         -587.57241498,  3350.96000484, -1281.95237654,  1049.39774068,
#         -325.09833329,  1234.56356082, -1647.05767912, -1439.09231561,
#         1586.17244355,  -262.31911551,  6873.60567462,    18.06574887,
#         -183.15675072,  -370.01645988,  -802.0342432 ,  1229.54627347,
#        -1313.96976561, -1313.96976561, -1313.96976561,  3732.34676272,
#         -994.49539128,  -678.54062994, -1485.35952487,  1616.26264385,
#         2811.62119964,  1110.59080537,  2603.44679345, -1029.11155931,
#          227.56137142,   227.56137142,  2381.6546595 ,   450.57691362,
#          680.94803224])

# %%
sgd.intercept_
# Out:
# array([32357.60102899])

# %%
sgd.n_iter_
# Out:
# 10

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
ypred = neigh.predict(X_test_scaled)

# %%
result["Predictions_2-NN"] = np.reshape(ypred,ypred.shape[0])

# %%
result["Error_2-NN"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)

# %%
#Tuning the value of K in KNN
from sklearn.model_selection import GridSearchCV

k_range = list(range(1, 10))
param_grid = dict(n_neighbors=k_range)

knn = KNeighborsRegressor()
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='neg_mean_absolute_error', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search=grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 10 folds for each of 9 candidates, totalling 90 fits

# %%
print(grid_search.best_params_)
# Out:
# {'n_neighbors': 8}

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

cv = KFold(n_splits=5, random_state=1, shuffle=True)

knn = KNeighborsRegressor()

scores = cross_val_score(knn, X_train_scaled, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# report performance
print('Negative_MAE: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))
# Out:
# Negative_MAE: -14956.463 (1011.102)

# %%
scores
# Out:
# array([-14592.60266667, -14818.30133333, -15360.93866667, -13457.368     ,
#        -16553.10666667])

# %% [markdown]
# # K Nearest Neighbours

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import matplotlib.ticker as ticker
# %matplotlib inline

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
#Train Model and Predict
k = 4  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
Pred_y = neigh.predict(X_test)
print("Accuracy of model at K=4 is",metrics.accuracy_score(y_test, Pred_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ebb34c0f3a86> in <module>()
#       1 from sklearn import preprocessing
# ----> 2 X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
#       3
#       4 from sklearn.model_selection import train_test_split
#       5 X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
#
# NameError: name 'X' is not defined

# %%
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(X_train,y_train)
 pred_i = knn.predict(X_test)
 pred_i = pred_i.reshape(100,1)
 error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-90c76f6b8ba9> in <module>()
#       1 error_rate = []
#       2 for i in range(1,40):
# ----> 3  knn = KNeighborsClassifier(n_neighbors=i)
#       4  knn.fit(X_train,y_train)
#       5  pred_i = knn.predict(X_test)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
acc = []
# Will take some time
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(X_train,y_train)
    yhat = neigh.predict(X_test)
    acc.append(metrics.accuracy_score(y_test, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %% [markdown]
# Therefore the Maximum accuracy which can be reached via k nearest neighbours is 2%

# %% [markdown]
# # K Nearest Neighbours

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

x_train_scaled = scaler.fit_transform(X_train)
x_train = pd.DataFrame(x_train_scaled)

x_test_scaled = scaler.fit_transform(X_test)
x_test = pd.DataFrame(x_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fb5d8c565d1d> in <module>()
#       2 scaler = MinMaxScaler(feature_range=(0, 1))
#       3
# ----> 4 x_train_scaled = scaler.fit_transform(X_train)
#       5 x_train = pd.DataFrame(x_train_scaled)
#       6
#
# NameError: name 'X_train' is not defined

# %%
#import required packages
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(x_train, y_train)  #fit the model
    pred=model.predict(x_test) #make prediction on test set
    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 23066.56942416882
# RMSE value for k=  2 is: 21887.552054135704
# RMSE value for k=  3 is: 21361.329064690708
# RMSE value for k=  4 is: 20056.290767627623
# RMSE value for k=  5 is: 20139.15956476834
# RMSE value for k=  6 is: 20373.477584145192
# RMSE value for k=  7 is: 20647.588201985614
# RMSE value for k=  8 is: 20011.10548482236
# RMSE value for k=  9 is: 20260.25646495018
# RMSE value for k=  10 is: 20272.1148771089
# RMSE value for k=  11 is: 20241.54527899415
# RMSE value for k=  12 is: 20385.363798955463
# RMSE value for k=  13 is: 20236.04682299012
# RMSE value for k=  14 is: 20161.13785165077
# RMSE value for k=  15 is: 20421.675645881754
# RMSE value for k=  16 is: 20485.335093008645
# RMSE value for k=  17 is: 20719.349438729656
# RMSE value for k=  18 is: 20789.007145385636
# RMSE value for k=  19 is: 20823.656703903427
# RMSE value for k=  20 is: 20939.579577110067

# %%
#plotting the rmse values against k values
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()

# %%
test_scaled = scaler.fit_transform(X_test)
test = pd.DataFrame(test_scaled)

#predicting on the test set and creating submission file
predict = model.predict(test)

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}

knn = neighbors.KNeighborsRegressor()

model = GridSearchCV(knn, params, cv=5)
model.fit(x_train,y_train)
model.best_params_
# Out:
# {'n_neighbors': 9}

# %% [markdown]
# # From Book

# %% [markdown]
# ## Linear Regression

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import sklearn

# %%
df = pd.read_excel("data.xlsx")

# %% [markdown]
# How to know which feature is Important?

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X = df.drop(['SalesID','SalePrice'],axis = 1)
y = df[['SalePrice']]
bestfeatures = SelectKBest(score_func=chi2, k=20)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  
print(featureScores.nlargest(20,'Score'))
# Out:
#                        Specs         Score
# 0                  MachineID  2.468055e+09
# 1                    ModelID  9.723086e+07
# 7                fiModelDesc  2.753253e+06
# 11         fiModelDescriptor  2.221250e+06
# 8                fiBaseModel  1.037857e+06
# 10             fiModelSeries  8.676910e+05
# 9            fiSecondaryDesc  7.257544e+05
# 4                   YearMade  6.625984e+05
# 38           Hydraulics_Flow  2.956044e+05
# 13        fiProductClassDesc  2.480238e+05
# 29                Hydraulics  1.604305e+05
# 34                 Tire_Size  1.526084e+05
# 41              Stick_Length  1.323367e+05
# 40   Undercarriage_Pad_Width  1.182379e+05
# 3               auctioneerID  1.003155e+05
# 5   MachineHoursCurrentMeter  1.003155e+05
# 53             saleDayOfYear  1.003155e+05
# 36            Coupler_System  9.856822e+04
# 37            Grouser_Tracks  9.808870e+04
# 23              Transmission  9.339600e+04

# %%
import seaborn as sns
X = df.drop(['SalesID','SalePrice'],axis = 1)
y = df[['SalePrice']]
corrmat = df.corr()
top_corr_features = corrmat.index

# %%
plt.figure(figsize=(50,50))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X = df[['MachineID','ModelID','fiModelDesc','fiModelDescriptor','fiBaseModel','fiModelSeries','fiSecondaryDesc','YearMade','Hydraulics_Flow','fiProductClassDesc','Hydraulics','Tire_Size','Stick_Length','Undercarriage_Pad_Width','auctioneerID','MachineHoursCurrentMeter','saleDayOfYear','Coupler_System','Grouser_Tracks','Transmission']]
y = df[['SalePrice']]
#X = df.drop(["SalePrice"],axis = 1)
#X = df.drop(["datasource"],axis = 1)
#y = df[['SalePrice']]

# %%
lin_reg_model = sklearn.linear_model.LinearRegression()
lin_reg_model.fit(X,y)
# clf = sklear.neighbors.KNeighborsRegressor(n_neighbours = 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-728190530007> in <module>()
# ----> 1 lin_reg_model = sklearn.linear_model.LinearRegression()
#       2 lin_reg_model.fit(X,y)
#       3 # clf = sklear.neighbors.KNeighborsRegressor(n_neighbours = 3)
#
# AttributeError: module 'sklearn' has no attribute 'linear_model'

# %%
# Split the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression().fit(X_train_scaled,y_train)
y_pred = linear_model.predict(X_test_scaled)

# %%
result = pd.DataFrame()

# %%
y_pred
# Out:
# array([[29626.20743912],
#        [30798.22921407],
#        [34318.1234251 ],
#        ...,
#        [37611.20504578],
#        [26701.6000415 ],
#        [39716.8829738 ]])

# %%
result["Predictions_LR"] = np.reshape(y_pred,90000)

# %%
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
mean_absolute_error(result["Actual"],result["Predictions_LR"])
# Out:
# 13635.574479378114

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 19047.078078759416

# %%
result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.3105366473134781

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeRegressor 
tree_reg = DecisionTreeRegressor()
tree_reg.fit(X_train,y_train)
y_pred = tree_reg.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
mean_absolute_error(result["Actual"],result["Predictions_LR"])
# Out:
# 8719.962466666666

# %%
from sklearn.metrics import mean_squared_error
tree_mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 14082.35841478345

# %%
result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.623118126849124

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_reg,X_train,y_train,scoring = "neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-scores)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-98153317349b> in <module>()
#       1 from sklearn.model_selection import cross_val_score
# ----> 2 scores = cross_val_score(tree_reg,X_train,y_train,scoring = "neg_mean_squared_error",cv=10)
#       3 rmse_scores = np.sqrt(-scores)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     518         fit_params=fit_params,
#     519         pre_dispatch=pre_dispatch,
# --> 520         error_score=error_score,
#     521     )
#     522     return cv_results["test_score"]
#
# ...

# %%
def display_scores(scores):
    print("Scores:",scores)
    print("Mean:",scores.mean())
    print("Standard Deviation:",scores.std())

# %%
display_scores(rmse_scores)
# Out:
# Scores: [14143.33174168 14226.02950434 14116.03240897 14067.62383261
#  14348.67216875 14230.53323428 14283.67644135 14072.45581045
#  14326.50285729 14011.32638591]
# Mean: 14182.618438563553
# Standard Deviation: 111.06183444135512

# %%
lin_scores = cross_val_score(tree_reg,X_train,y_train,scoring = "neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_scores)
# Out:
# Scores: [-1.97266522e+08 -2.02446629e+08 -1.97520900e+08 -1.98919119e+08
#  -2.07214079e+08 -2.03000865e+08 -2.02111090e+08 -1.97855069e+08
#  -2.04035440e+08 -1.96359802e+08]
# Mean: -200672951.57285237
# Standard Deviation: 3404186.8285698947

# %% [markdown]
# Therefore Decision Trees Work better than Linear Regressor

# %% [markdown]
# ## K Nearest Neighbours

# %%
#Tuning the value of K in KNN
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

k_range = list(range(1, 10))
param_grid = dict(n_neighbors=k_range)

knn = KNeighborsRegressor()
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='neg_mean_absolute_error', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search=grid.fit(X_train_scaled, y_train)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import neighbors
knn = KNeighborsRegressor()
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train_scaled, y_train)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = np.sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)

# %%
print(grid_search.best_params_)

# %%
neigh = KNeighborsRegressor(n_neighbors=8)
neigh.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=8)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import neighbors
knn = KNeighborsRegressor()
rmse_val = [] #to store rmse values for different k
model = neighbors.KNeighborsRegressor(n_neighbors = 8)
model.fit(X_train_scaled, y_train)  #fit the model
pred=model.predict(X_test) #make prediction on test set
error = np.sqrt(mean_squared_error(y_test,pred)) #calculate rmse
#rmse_val.append(error) #store rmse values
print('RMSE value for k= ' , K , 'is:', error)   # K = 8
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# RMSE value for k=  2 is: 24488.025356319224

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

cv = KFold(n_splits=5, random_state=1, shuffle=True)

knn = KNeighborsRegressor()

scores = cross_val_score(knn, X_train_scaled, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# report performance
print('Negative_MAE: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor()

# %%
y_pred = forest_reg.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
mean_absolute_error(result["Actual"],result["Predictions_LR"])
# Out:
# 6732.434801655202

# %%
error = np.sqrt(mean_squared_error(y_test,pred)) #calculate rmse
print(error)
# Out:
# 24488.025356319224

# %%
result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7917275484924882

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [
 {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
 {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
 ]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
 scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 12251.610918974588 {'max_features': 2, 'n_estimators': 3}
# 10987.547035081569 {'max_features': 2, 'n_estimators': 10}
# 10608.923536087032 {'max_features': 2, 'n_estimators': 30}
# 11978.302011917265 {'max_features': 4, 'n_estimators': 3}
# 10794.932547674654 {'max_features': 4, 'n_estimators': 10}
# 10448.89180581813 {'max_features': 4, 'n_estimators': 30}
# 11863.921483460568 {'max_features': 6, 'n_estimators': 3}
# 10787.329431487404 {'max_features': 6, 'n_estimators': 10}
# 10431.410148811938 {'max_features': 6, 'n_estimators': 30}
# 11834.560728428818 {'max_features': 8, 'n_estimators': 3}
# 10774.625515542966 {'max_features': 8, 'n_estimators': 10}
# 10425.655430588373 {'max_features': 8, 'n_estimators': 30}
# 12012.056122987313 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 11046.927726946265 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 12003.81471180385 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X, y)

y_pred = lasso_reg.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ",mean_absolute_error(result["Actual"],result["Predictions_LR"]))

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
rmse = np.sqrt(mse)
print("RMSE",rmse)

result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
print("R2 Score: ",r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  13645.182648349832
# RMSE 19044.654575352084
# R2 Score:  0.3107120873968213
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.486e+13, tolerance: 1.564e+10
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive

# %%
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(X, y)

y_pred = elastic_net.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ",mean_absolute_error(result["Actual"],result["Predictions_LR"]))

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
rmse = np.sqrt(mse)
print("RMSE",rmse)

result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
print("R2 Score: ",r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  13648.033039616563
# RMSE 19057.579073594632
# R2 Score:  0.3097762107929236
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.909e+13, tolerance: 1.564e+10
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive

# %%
from sklearn.base import clone
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(max_iter=1, warm_start=True, penalty=None,
 learning_rate="constant", eta0=0.0005)
minimum_val_error = float("inf")
best_epoch = None
best_model = None
for epoch in range(1000):
 sgd_reg.fit(X_train_scaled, y_train) # continues where it left off
 y_val_predict = sgd_reg.predict(X_test_scaled)
 val_error = mean_squared_error(y_test,pred)
 if val_error < minimum_val_error:
    minimum_val_error = val_error
    best_epoch = epoch
    best_model = clone(sgd_reg)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# ...

# %%
y_pred = sgd_reg.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ",mean_absolute_error(result["Actual"],result["Predictions_LR"]))

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
rmse = np.sqrt(mse)
print("RMSE",rmse)

result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
print("R2 Score: ",r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  5952627047.976896
# RMSE 6265262333.339397
# R2 Score:  -74598996071.57057
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but SGDRegressor was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
from sklearn.svm import LinearSVR
svm_reg = LinearSVR(epsilon=1.5)
svm_reg.fit(X_train, y_train)

y_pred = svm_reg.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ",mean_absolute_error(result["Actual"],result["Predictions_LR"]))

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
rmse = np.sqrt(mse)
print("RMSE",rmse)

result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
print("R2 Score: ",r2_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error:  17792.80044816753
# RMSE 24955.28625928694
# R2 Score:  -0.183530827998021
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,

# %%
from sklearn.svm import SVR
svm_poly_reg = SVR(kernel="poly", degree=2, C=100, epsilon=0.1)
svm_poly_reg.fit(X_train, y_train)

y_pred = svm_poly_reg.predict(X_test)
result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ",mean_absolute_error(result["Actual"],result["Predictions_LR"]))

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
rmse = np.sqrt(mse)
print("RMSE",rmse)

result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
print("R2 Score: ",r2_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Ensemble Learning

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg1 = DecisionTreeRegressor(max_depth=2)
tree_reg1.fit(X_train, y_train)

y2 = y - tree_reg1.predict(y_test)
tree_reg2 = DecisionTreeRegressor(max_depth=2)
tree_reg2.fit(X_train, y_train)

y3 = y2 - tree_reg2.predict(y_test)
tree_reg3 = DecisionTreeRegressor(max_depth=2)
tree_reg3.fit(X_train, y_train)

y_pred = sum(tree.predict(X_test) for tree in (tree_reg1, tree_reg2, tree_reg3))

result = pd.DataFrame()
result["Predictions_LR"] = np.reshape(y_pred,90000)
result["Actual"] = y_test.values
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error: ",mean_absolute_error(result["Actual"],result["Predictions_LR"]))

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(result["Actual"],result["Predictions_LR"])
rmse = np.sqrt(mse)
print("RMSE",rmse)

result["Error_LR"] = np.abs(result["Actual"].values - result["Predictions_LR"].values)
SAE = result["Error_LR"].sum() #Sum of Absolute Errors
from sklearn.metrics import r2_score
print("R2 Score: ",r2_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - SalePrice
# Feature names seen at fit time, yet now missing:
# - Coupler_System
# - Grouser_Tracks
# - Hydraulics
# - Hydraulics_Flow
# - MachineHoursCurrentMeter
# - ...
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-ccec9de4d2f5> in <module>()
#       3 tree_reg1.fit(X_train, y_train)
#       4
# ----> 5 y2 = y - tree_reg1.predict(y_test)
#       6 tree_reg2 = DecisionTreeRegressor(max_depth=2)
#       7 tree_reg2.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     465         """
# ...
